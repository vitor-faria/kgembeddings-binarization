# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from datetime import datetime 
import time
from os import stat
import pandas as pd
from time import sleep
import pickle


with open('geval_entities.pickle', 'rb') as file:
    geval_entities = pickle.load(file)

# %%
# !mkdir geval_embeddings

# %%
embedding_models = [
    'rdf2vec-cbow',
    'rdf2vec-cbow-oa',
    'rdf2vec-sg',
    'rdf2vec-sg-oa',
    'non-rdf2vec-ComplEx',
    'non-rdf2vec-DistMult',
    'non-rdf2vec-RESCAL',
    'non-rdf2vec-RotatE',
    'non-rdf2vec-TransE-L1',
    'non-rdf2vec-TransE-L2',
    'non-rdf2vec-TransR',
]

model_variants = [
    '-200-original',
    '-200-avgbin',
    '-128-autoencoded',
    '-256-autoencoded',
    '-512-autoencoded',
]

embedding_txt_filenames = [em+mv for mv in model_variants for em in embedding_models]

for embedding_txt_filename in embedding_txt_filenames:
    with open(f"embeddings/{embedding_txt_filename}.txt", "r") as file:
        lines = file.readlines()

    with open(f"geval_embeddings/geval-{embedding_txt_filename}.txt", "w") as file:
        rows_count = 0
        for line in lines:
            if line.split()[0] in geval_entities:
                file.write(line)
                rows_count += 1
    
    print(f"geval_embeddings/geval-{embedding_txt_filename}.txt : {rows_count} entities filtered")
# Out:
# geval_embeddings/geval-rdf2vec-cbow-200-original.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-200-original.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-200-original.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-200-original.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-200-avgbin.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-200-avgbin.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-200-avgbin.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-200-avgbin.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-128-autoencoded.txt : 21540 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-128-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-128-autoencoded.txt : 18186 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-128-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-128-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-256-autoencoded.txt : 21540 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-256-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-256-autoencoded.txt : 18186 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-256-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-256-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-512-autoencoded.txt : 21540 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-512-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-512-autoencoded.txt : 18186 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-512-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-512-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-512-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-512-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-512-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-512-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-512-autoencoded.txt : 21644 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-512-autoencoded.txt : 21644 entities filtered

# %%
from evaluation_framework.manager import FrameworkManager

evaluation_manager = FrameworkManager()
# Out:
# Start evaluation...

# %%
def run_task_for_all_vectors(task_name, embedding_txt_filenames, similarity_metric='manhattan', top_k=10):
    metadata_json = []
    for embedding_txt_filename in embedding_txt_filenames:
        file_size = stat(f"geval_embeddings/geval-{embedding_txt_filename}.txt")
        vector_size = int(embedding_txt_filename.split('-')[-2])
        print(f"Vector file: {embedding_txt_filename}; Dimensions: {vector_size}")

        start_time = datetime.now() 
        evaluation_manager.evaluate(
            f"geval_embeddings/geval-{embedding_txt_filename}.txt",
            vector_size=vector_size,
            debugging_mode=False,
            tasks=[task_name],
            similarity_metric=similarity_metric,
            top_k=top_k,
        )
        end_time = datetime.now()
        metadata_json.append({
            "embedding_file": embedding_txt_filename,
            "task_name": task_name,
            "file_size": file_size.st_size,
            "time_to_run": end_time - start_time,
        })
        sleep(1)
        
    return metadata_json

# %%
task_name = 'DocumentSimilarity'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
metadata_df.to_csv(f'{task_name}_metadata.csv', index=False)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Document similarity finished

# %%
metadata_df
# Out:
#                            embedding_file           task_name  file_size  \
# 0               rdf2vec-cbow-200-original  DocumentSimilarity   88101211
# 1            rdf2vec-cbow-oa-200-original  DocumentSimilarity   89030608
# 2                 rdf2vec-sg-200-original  DocumentSimilarity   74793299
# 3              rdf2vec-sg-oa-200-original  DocumentSimilarity   87883088
# 4        non-rdf2vec-ComplEx-200-original  DocumentSimilarity   88154366
# 5       non-rdf2vec-DistMult-200-original  DocumentSimilarity   88088311
# 6         non-rdf2vec-RESCAL-200-original  DocumentSimilarity   89677247
# 7         non-rdf2vec-RotatE-200-original  DocumentSimilarity   90695298
# 8      non-rdf2vec-TransE-L1-200-original  DocumentSimilarity   91713818
# 9      non-rdf2vec-TransE-L2-200-original  DocumentSimilarity   87218400
# 10        non-rdf2vec-TransR-200-original  DocumentSimilarity   92994398
# 11                rdf2vec-cbow-200-avgbin  DocumentSimilarity    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  DocumentSimilarity    9690774
# 13                  rdf2vec-sg-200-avgbin  DocumentSimilarity    8199564
# 14               rdf2vec-sg-oa-200-avgbin  DocumentSimilarity    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  DocumentSimilarity    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  DocumentSimilarity    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  DocumentSimilarity    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  DocumentSimilarity    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  DocumentSimilarity    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  DocumentSimilarity    9752021
# 21          non-rdf2vec-TransR-200-avgbin  DocumentSimilarity    9752021
# 22           rdf2vec-cbow-128-autoencoded  DocumentSimilarity    6591527
# 23        rdf2vec-cbow-oa-128-autoencoded  DocumentSimilarity    6589734
# 24             rdf2vec-sg-128-autoencoded  DocumentSimilarity    5572764
# 25          rdf2vec-sg-oa-128-autoencoded  DocumentSimilarity    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  DocumentSimilarity    6622879
# 27   non-rdf2vec-DistMult-128-autoencoded  DocumentSimilarity    6622879
# 28     non-rdf2vec-RESCAL-128-autoencoded  DocumentSimilarity    6622879
# 29     non-rdf2vec-RotatE-128-autoencoded  DocumentSimilarity    6622879
# 30  non-rdf2vec-TransE-L1-128-autoencoded  DocumentSimilarity    6622879
# 31  non-rdf2vec-TransE-L2-128-autoencoded  DocumentSimilarity    6622879
# 32     non-rdf2vec-TransR-128-autoencoded  DocumentSimilarity    6622879
# 33           rdf2vec-cbow-256-autoencoded  DocumentSimilarity   12105767
# 34        rdf2vec-cbow-oa-256-autoencoded  DocumentSimilarity   12102694
# 35             rdf2vec-sg-256-autoencoded  DocumentSimilarity   10228380
# 36          rdf2vec-sg-oa-256-autoencoded  DocumentSimilarity   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  DocumentSimilarity   12163743
# 38   non-rdf2vec-DistMult-256-autoencoded  DocumentSimilarity   12163743
# 39     non-rdf2vec-RESCAL-256-autoencoded  DocumentSimilarity   12163743
# 40     non-rdf2vec-RotatE-256-autoencoded  DocumentSimilarity   12163743
# 41  non-rdf2vec-TransE-L1-256-autoencoded  DocumentSimilarity   12163743
# 42  non-rdf2vec-TransE-L2-256-autoencoded  DocumentSimilarity   12163743
# 43     non-rdf2vec-TransR-256-autoencoded  DocumentSimilarity   12163743
# 44           rdf2vec-cbow-512-autoencoded  DocumentSimilarity   23134247
# 45        rdf2vec-cbow-oa-512-autoencoded  DocumentSimilarity   23128614
# 46             rdf2vec-sg-512-autoencoded  DocumentSimilarity   19539612
# 47          rdf2vec-sg-oa-512-autoencoded  DocumentSimilarity   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  DocumentSimilarity   23245471
# 49   non-rdf2vec-DistMult-512-autoencoded  DocumentSimilarity   23245471
# 50     non-rdf2vec-RESCAL-512-autoencoded  DocumentSimilarity   23245471
# 51     non-rdf2vec-RotatE-512-autoencoded  DocumentSimilarity   23245471
# 52  non-rdf2vec-TransE-L1-512-autoencoded  DocumentSimilarity   23245471
# 53  non-rdf2vec-TransE-L2-512-autoencoded  DocumentSimilarity   23245471
# 54     non-rdf2vec-TransR-512-autoencoded  DocumentSimilarity   23245471
#
#        time_to_run
# 0  00:00:13.020777
# 1  00:00:11.648480
# 2  00:00:11.738162
# 3  00:00:11.704351
# 4  00:00:11.810177
# 5  00:00:11.628429
# 6  00:00:11.648436
# 7  00:00:11.664130
# 8  00:00:12.061363
# 9  00:00:11.721442
# 10 00:00:11.644703
# 11 00:00:11.516253
# 12 00:00:11.378685
# 13 00:00:11.384551
# 14 00:00:11.398376
# 15 00:00:11.410540
# 16 00:00:11.370508
# 17 00:00:11.380007
# 18 00:00:11.556925
# 19 00:00:11.809213
# 20 00:00:11.374480
# 21 00:00:11.380219
# 22 00:00:08.517038
# 23 00:00:08.660322
# 24 00:00:08.464160
# 25 00:00:08.529413
# 26 00:00:08.507080
# 27 00:00:08.465542
# 28 00:00:08.481388
# 29 00:00:08.595790
# 30 00:00:08.559201
# 31 00:00:08.591684
# 32 00:00:08.569719
# 33 00:00:14.073274
# 34 00:00:14.080369
# 35 00:00:13.935781
# 36 00:00:13.830843
# 37 00:00:14.115461
# 38 00:00:14.015301
# 39 00:00:14.268095
# 40 00:00:13.865398
# 41 00:00:13.968585
# 42 00:00:13.976139
# 43 00:00:14.230806
# 44 00:00:26.958970
# 45 00:00:28.665318
# 46 00:00:27.265032
# 47 00:00:28.705373
# 48 00:00:27.727690
# 49 00:00:28.405935
# 50 00:00:27.735452
# 51 00:00:28.304023
# 52 00:00:27.859251
# 53 00:00:28.276200
# 54 00:00:28.158169

# %%
task_name = 'EntityRelatedness'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames, similarity_metric='cosine')
metadata_df = pd.DataFrame(metadata_json)
metadata_df.to_csv(f'{task_name}_metadata.csv', index=False)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Entity Relatedness finished

# %%
metadata_df
# Out:
#                            embedding_file          task_name  file_size  \
# 0               rdf2vec-cbow-200-original  EntityRelatedness   88101211
# 1            rdf2vec-cbow-oa-200-original  EntityRelatedness   89030608
# 2                 rdf2vec-sg-200-original  EntityRelatedness   74793299
# 3              rdf2vec-sg-oa-200-original  EntityRelatedness   87883088
# 4        non-rdf2vec-ComplEx-200-original  EntityRelatedness   88154366
# 5       non-rdf2vec-DistMult-200-original  EntityRelatedness   88088311
# 6         non-rdf2vec-RESCAL-200-original  EntityRelatedness   89677247
# 7         non-rdf2vec-RotatE-200-original  EntityRelatedness   90695298
# 8      non-rdf2vec-TransE-L1-200-original  EntityRelatedness   91713818
# 9      non-rdf2vec-TransE-L2-200-original  EntityRelatedness   87218400
# 10        non-rdf2vec-TransR-200-original  EntityRelatedness   92994398
# 11                rdf2vec-cbow-200-avgbin  EntityRelatedness    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  EntityRelatedness    9690774
# 13                  rdf2vec-sg-200-avgbin  EntityRelatedness    8199564
# 14               rdf2vec-sg-oa-200-avgbin  EntityRelatedness    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  EntityRelatedness    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  EntityRelatedness    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  EntityRelatedness    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  EntityRelatedness    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  EntityRelatedness    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  EntityRelatedness    9752021
# 21          non-rdf2vec-TransR-200-avgbin  EntityRelatedness    9752021
# 22           rdf2vec-cbow-128-autoencoded  EntityRelatedness    6591527
# 23        rdf2vec-cbow-oa-128-autoencoded  EntityRelatedness    6589734
# 24             rdf2vec-sg-128-autoencoded  EntityRelatedness    5572764
# 25          rdf2vec-sg-oa-128-autoencoded  EntityRelatedness    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  EntityRelatedness    6622879
# 27   non-rdf2vec-DistMult-128-autoencoded  EntityRelatedness    6622879
# 28     non-rdf2vec-RESCAL-128-autoencoded  EntityRelatedness    6622879
# 29     non-rdf2vec-RotatE-128-autoencoded  EntityRelatedness    6622879
# 30  non-rdf2vec-TransE-L1-128-autoencoded  EntityRelatedness    6622879
# 31  non-rdf2vec-TransE-L2-128-autoencoded  EntityRelatedness    6622879
# 32     non-rdf2vec-TransR-128-autoencoded  EntityRelatedness    6622879
# 33           rdf2vec-cbow-256-autoencoded  EntityRelatedness   12105767
# 34        rdf2vec-cbow-oa-256-autoencoded  EntityRelatedness   12102694
# 35             rdf2vec-sg-256-autoencoded  EntityRelatedness   10228380
# 36          rdf2vec-sg-oa-256-autoencoded  EntityRelatedness   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  EntityRelatedness   12163743
# 38   non-rdf2vec-DistMult-256-autoencoded  EntityRelatedness   12163743
# 39     non-rdf2vec-RESCAL-256-autoencoded  EntityRelatedness   12163743
# 40     non-rdf2vec-RotatE-256-autoencoded  EntityRelatedness   12163743
# 41  non-rdf2vec-TransE-L1-256-autoencoded  EntityRelatedness   12163743
# 42  non-rdf2vec-TransE-L2-256-autoencoded  EntityRelatedness   12163743
# 43     non-rdf2vec-TransR-256-autoencoded  EntityRelatedness   12163743
# 44           rdf2vec-cbow-512-autoencoded  EntityRelatedness   23134247
# 45        rdf2vec-cbow-oa-512-autoencoded  EntityRelatedness   23128614
# 46             rdf2vec-sg-512-autoencoded  EntityRelatedness   19539612
# 47          rdf2vec-sg-oa-512-autoencoded  EntityRelatedness   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  EntityRelatedness   23245471
# 49   non-rdf2vec-DistMult-512-autoencoded  EntityRelatedness   23245471
# 50     non-rdf2vec-RESCAL-512-autoencoded  EntityRelatedness   23245471
# 51     non-rdf2vec-RotatE-512-autoencoded  EntityRelatedness   23245471
# 52  non-rdf2vec-TransE-L1-512-autoencoded  EntityRelatedness   23245471
# 53  non-rdf2vec-TransE-L2-512-autoencoded  EntityRelatedness   23245471
# 54     non-rdf2vec-TransR-512-autoencoded  EntityRelatedness   23245471
#
#        time_to_run
# 0  00:00:01.744175
# 1  00:00:01.567031
# 2  00:00:01.366559
# 3  00:00:01.559937
# 4  00:00:01.624066
# 5  00:00:01.596018
# 6  00:00:01.586189
# 7  00:00:01.588823
# 8  00:00:01.634538
# 9  00:00:01.917518
# 10 00:00:01.994120
# 11 00:00:01.075332
# 12 00:00:01.065862
# 13 00:00:00.988937
# 14 00:00:01.070493
# 15 00:00:01.081417
# 16 00:00:01.079638
# 17 00:00:01.071931
# 18 00:00:01.229905
# 19 00:00:01.084507
# 20 00:00:01.171296
# 21 00:00:01.089206
# 22 00:00:00.876556
# 23 00:00:00.874732
# 24 00:00:00.823960
# 25 00:00:00.872841
# 26 00:00:00.873261
# 27 00:00:00.871802
# 28 00:00:00.881212
# 29 00:00:00.881444
# 30 00:00:00.880731
# 31 00:00:00.876661
# 32 00:00:00.878838
# 33 00:00:01.361358
# 34 00:00:01.235313
# 35 00:00:01.118308
# 36 00:00:01.223024
# 37 00:00:01.338421
# 38 00:00:01.275023
# 39 00:00:01.247379
# 40 00:00:01.254375
# 41 00:00:01.243432
# 42 00:00:01.251106
# 43 00:00:01.243484
# 44 00:00:02.242935
# 45 00:00:02.034848
# 46 00:00:01.795468
# 47 00:00:01.973806
# 48 00:00:02.254325
# 49 00:00:02.052827
# 50 00:00:01.985254
# 51 00:00:02.055066
# 52 00:00:02.109026
# 53 00:00:02.109118
# 54 00:00:02.089877

# %%
task_name = 'SemanticAnalogies'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
metadata_df.to_csv(f'{task_name}_metadata.csv', index=False)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Semantic Analogies finished

# %%
metadata_df
# Out:
#                            embedding_file          task_name  file_size  \
# 0               rdf2vec-cbow-200-original  SemanticAnalogies   88101211
# 1            rdf2vec-cbow-oa-200-original  SemanticAnalogies   89030608
# 2                 rdf2vec-sg-200-original  SemanticAnalogies   74793299
# 3              rdf2vec-sg-oa-200-original  SemanticAnalogies   87883088
# 4        non-rdf2vec-ComplEx-200-original  SemanticAnalogies   88154366
# 5       non-rdf2vec-DistMult-200-original  SemanticAnalogies   88088311
# 6         non-rdf2vec-RESCAL-200-original  SemanticAnalogies   89677247
# 7         non-rdf2vec-RotatE-200-original  SemanticAnalogies   90695298
# 8      non-rdf2vec-TransE-L1-200-original  SemanticAnalogies   91713818
# 9      non-rdf2vec-TransE-L2-200-original  SemanticAnalogies   87218400
# 10        non-rdf2vec-TransR-200-original  SemanticAnalogies   92994398
# 11                rdf2vec-cbow-200-avgbin  SemanticAnalogies    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  SemanticAnalogies    9690774
# 13                  rdf2vec-sg-200-avgbin  SemanticAnalogies    8199564
# 14               rdf2vec-sg-oa-200-avgbin  SemanticAnalogies    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  SemanticAnalogies    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  SemanticAnalogies    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  SemanticAnalogies    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  SemanticAnalogies    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  SemanticAnalogies    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  SemanticAnalogies    9752021
# 21          non-rdf2vec-TransR-200-avgbin  SemanticAnalogies    9752021
# 22           rdf2vec-cbow-128-autoencoded  SemanticAnalogies    6591527
# 23        rdf2vec-cbow-oa-128-autoencoded  SemanticAnalogies    6589734
# 24             rdf2vec-sg-128-autoencoded  SemanticAnalogies    5572764
# 25          rdf2vec-sg-oa-128-autoencoded  SemanticAnalogies    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  SemanticAnalogies    6622879
# 27   non-rdf2vec-DistMult-128-autoencoded  SemanticAnalogies    6622879
# 28     non-rdf2vec-RESCAL-128-autoencoded  SemanticAnalogies    6622879
# 29     non-rdf2vec-RotatE-128-autoencoded  SemanticAnalogies    6622879
# 30  non-rdf2vec-TransE-L1-128-autoencoded  SemanticAnalogies    6622879
# 31  non-rdf2vec-TransE-L2-128-autoencoded  SemanticAnalogies    6622879
# 32     non-rdf2vec-TransR-128-autoencoded  SemanticAnalogies    6622879
# 33           rdf2vec-cbow-256-autoencoded  SemanticAnalogies   12105767
# 34        rdf2vec-cbow-oa-256-autoencoded  SemanticAnalogies   12102694
# 35             rdf2vec-sg-256-autoencoded  SemanticAnalogies   10228380
# 36          rdf2vec-sg-oa-256-autoencoded  SemanticAnalogies   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  SemanticAnalogies   12163743
# 38   non-rdf2vec-DistMult-256-autoencoded  SemanticAnalogies   12163743
# 39     non-rdf2vec-RESCAL-256-autoencoded  SemanticAnalogies   12163743
# 40     non-rdf2vec-RotatE-256-autoencoded  SemanticAnalogies   12163743
# 41  non-rdf2vec-TransE-L1-256-autoencoded  SemanticAnalogies   12163743
# 42  non-rdf2vec-TransE-L2-256-autoencoded  SemanticAnalogies   12163743
# 43     non-rdf2vec-TransR-256-autoencoded  SemanticAnalogies   12163743
# 44           rdf2vec-cbow-512-autoencoded  SemanticAnalogies   23134247
# 45        rdf2vec-cbow-oa-512-autoencoded  SemanticAnalogies   23128614
# 46             rdf2vec-sg-512-autoencoded  SemanticAnalogies   19539612
# 47          rdf2vec-sg-oa-512-autoencoded  SemanticAnalogies   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  SemanticAnalogies   23245471
# 49   non-rdf2vec-DistMult-512-autoencoded  SemanticAnalogies   23245471
# 50     non-rdf2vec-RESCAL-512-autoencoded  SemanticAnalogies   23245471
# 51     non-rdf2vec-RotatE-512-autoencoded  SemanticAnalogies   23245471
# 52  non-rdf2vec-TransE-L1-512-autoencoded  SemanticAnalogies   23245471
# 53  non-rdf2vec-TransE-L2-512-autoencoded  SemanticAnalogies   23245471
# 54     non-rdf2vec-TransR-512-autoencoded  SemanticAnalogies   23245471
#
#        time_to_run
# 0  00:00:21.333947
# 1  00:00:20.759903
# 2  00:00:00.822558
# 3  00:00:20.808519
# 4  00:00:21.903374
# 5  00:00:22.073671
# 6  00:00:21.912656
# 7  00:00:21.702357
# 8  00:00:21.906336
# 9  00:00:22.055592
# 10 00:00:21.701232
# 11 00:00:20.334000
# 12 00:00:20.625843
# 13 00:00:00.500979
# 14 00:00:20.102856
# 15 00:00:21.560303
# 16 00:00:21.272727
# 17 00:00:21.231646
# 18 00:00:21.692226
# 19 00:00:21.351203
# 20 00:00:21.113468
# 21 00:00:21.511234
# 22 00:00:17.445889
# 23 00:00:17.580033
# 24 00:00:00.367417
# 25 00:00:18.100120
# 26 00:00:17.843825
# 27 00:00:17.814575
# 28 00:00:18.167788
# 29 00:00:17.903651
# 30 00:00:17.796664
# 31 00:00:18.320301
# 32 00:00:17.821883
# 33 00:00:23.228612
# 34 00:00:23.413037
# 35 00:00:00.550554
# 36 00:00:23.288414
# 37 00:00:24.028749
# 38 00:00:24.293652
# 39 00:00:23.958288
# 40 00:00:24.243672
# 41 00:00:23.863558
# 42 00:00:24.150147
# 43 00:00:23.972522
# 44 00:00:34.923376
# 45 00:00:34.432224
# 46 00:00:00.861422
# 47 00:00:34.305882
# 48 00:00:35.450977
# 49 00:00:35.299709
# 50 00:00:35.550614
# 51 00:00:35.709962
# 52 00:00:35.435821
# 53 00:00:35.314596
# 54 00:00:35.217138

# %%
task_name = 'Clustering'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
metadata_df.to_csv(f'{task_name}_metadata.csv', index=False)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Clustering finished

# %%
metadata_df
# Out:
#                            embedding_file   task_name  file_size  \
# 0               rdf2vec-cbow-200-original  Clustering   88101211
# 1            rdf2vec-cbow-oa-200-original  Clustering   89030608
# 2                 rdf2vec-sg-200-original  Clustering   74793299
# 3              rdf2vec-sg-oa-200-original  Clustering   87883088
# 4        non-rdf2vec-ComplEx-200-original  Clustering   88154366
# 5       non-rdf2vec-DistMult-200-original  Clustering   88088311
# 6         non-rdf2vec-RESCAL-200-original  Clustering   89677247
# 7         non-rdf2vec-RotatE-200-original  Clustering   90695298
# 8      non-rdf2vec-TransE-L1-200-original  Clustering   91713818
# 9      non-rdf2vec-TransE-L2-200-original  Clustering   87218400
# 10        non-rdf2vec-TransR-200-original  Clustering   92994398
# 11                rdf2vec-cbow-200-avgbin  Clustering    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  Clustering    9690774
# 13                  rdf2vec-sg-200-avgbin  Clustering    8199564
# 14               rdf2vec-sg-oa-200-avgbin  Clustering    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  Clustering    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  Clustering    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  Clustering    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  Clustering    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  Clustering    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  Clustering    9752021
# 21          non-rdf2vec-TransR-200-avgbin  Clustering    9752021
# 22           rdf2vec-cbow-128-autoencoded  Clustering    6591527
# 23        rdf2vec-cbow-oa-128-autoencoded  Clustering    6589734
# 24             rdf2vec-sg-128-autoencoded  Clustering    5572764
# 25          rdf2vec-sg-oa-128-autoencoded  Clustering    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  Clustering    6622879
# 27   non-rdf2vec-DistMult-128-autoencoded  Clustering    6622879
# 28     non-rdf2vec-RESCAL-128-autoencoded  Clustering    6622879
# 29     non-rdf2vec-RotatE-128-autoencoded  Clustering    6622879
# 30  non-rdf2vec-TransE-L1-128-autoencoded  Clustering    6622879
# 31  non-rdf2vec-TransE-L2-128-autoencoded  Clustering    6622879
# 32     non-rdf2vec-TransR-128-autoencoded  Clustering    6622879
# 33           rdf2vec-cbow-256-autoencoded  Clustering   12105767
# 34        rdf2vec-cbow-oa-256-autoencoded  Clustering   12102694
# 35             rdf2vec-sg-256-autoencoded  Clustering   10228380
# 36          rdf2vec-sg-oa-256-autoencoded  Clustering   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  Clustering   12163743
# 38   non-rdf2vec-DistMult-256-autoencoded  Clustering   12163743
# 39     non-rdf2vec-RESCAL-256-autoencoded  Clustering   12163743
# 40     non-rdf2vec-RotatE-256-autoencoded  Clustering   12163743
# 41  non-rdf2vec-TransE-L1-256-autoencoded  Clustering   12163743
# 42  non-rdf2vec-TransE-L2-256-autoencoded  Clustering   12163743
# 43     non-rdf2vec-TransR-256-autoencoded  Clustering   12163743
# 44           rdf2vec-cbow-512-autoencoded  Clustering   23134247
# 45        rdf2vec-cbow-oa-512-autoencoded  Clustering   23128614
# 46             rdf2vec-sg-512-autoencoded  Clustering   19539612
# 47          rdf2vec-sg-oa-512-autoencoded  Clustering   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  Clustering   23245471
# 49   non-rdf2vec-DistMult-512-autoencoded  Clustering   23245471
# 50     non-rdf2vec-RESCAL-512-autoencoded  Clustering   23245471
# 51     non-rdf2vec-RotatE-512-autoencoded  Clustering   23245471
# 52  non-rdf2vec-TransE-L1-512-autoencoded  Clustering   23245471
# 53  non-rdf2vec-TransE-L2-512-autoencoded  Clustering   23245471
# 54     non-rdf2vec-TransR-512-autoencoded  Clustering   23245471
#
#        time_to_run
# 0  00:01:08.023447
# 1  00:00:39.010951
# 2  00:00:25.117615
# 3  00:00:35.823996
# 4  00:00:30.530081
# 5  00:00:30.015616
# 6  00:00:30.964916
# 7  00:00:30.149859
# 8  00:00:29.808124
# 9  00:00:29.628249
# 10 00:00:31.765854
# 11 00:00:52.564587
# 12 00:01:05.905903
# 13 00:00:44.491607
# 14 00:01:02.354277
# 15 00:01:16.893891
# 16 00:01:21.883124
# 17 00:01:11.445425
# 18 00:00:41.855176
# 19 00:00:53.589264
# 20 00:01:16.346046
# 21 00:00:59.195479
# 22 00:00:44.432920
# 23 00:00:56.761548
# 24 00:00:42.620212
# 25 00:00:59.144889
# 26 00:00:53.191036
# 27 00:00:50.120957
# 28 00:00:55.531463
# 29 00:00:30.714114
# 30 00:00:54.968011
# 31 00:00:51.055998
# 32 00:00:53.841195
# 33 00:01:23.903257
# 34 00:01:47.388048
# 35 00:01:12.894214
# 36 00:01:44.324600
# 37 00:01:51.441711
# 38 00:01:50.296839
# 39 00:01:41.815484
# 40 00:00:54.080578
# 41 00:01:29.865517
# 42 00:01:31.933448
# 43 00:01:25.754988
# 44 00:03:00.068297
# 45 00:03:27.919733
# 46 00:02:12.117990
# 47 00:03:19.107835
# 48 00:03:55.267853
# 49 00:03:52.898205
# 50 00:02:53.859995
# 51 00:01:44.577200
# 52 00:02:48.354449
# 53 00:02:51.988593
# 54 00:02:22.065046

# %%
task_name = 'Regression'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
metadata_df.to_csv(f'{task_name}_metadata.csv', index=False)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Regression finished

# %%
metadata_df
# Out:
#                            embedding_file   task_name  file_size  \
# 0               rdf2vec-cbow-200-original  Regression   88101211
# 1            rdf2vec-cbow-oa-200-original  Regression   89030608
# 2                 rdf2vec-sg-200-original  Regression   74793299
# 3              rdf2vec-sg-oa-200-original  Regression   87883088
# 4        non-rdf2vec-ComplEx-200-original  Regression   88154366
# 5       non-rdf2vec-DistMult-200-original  Regression   88088311
# 6         non-rdf2vec-RESCAL-200-original  Regression   89677247
# 7         non-rdf2vec-RotatE-200-original  Regression   90695298
# 8      non-rdf2vec-TransE-L1-200-original  Regression   91713818
# 9      non-rdf2vec-TransE-L2-200-original  Regression   87218400
# 10        non-rdf2vec-TransR-200-original  Regression   92994398
# 11                rdf2vec-cbow-200-avgbin  Regression    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  Regression    9690774
# 13                  rdf2vec-sg-200-avgbin  Regression    8199564
# 14               rdf2vec-sg-oa-200-avgbin  Regression    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  Regression    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  Regression    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  Regression    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  Regression    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  Regression    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  Regression    9752021
# 21          non-rdf2vec-TransR-200-avgbin  Regression    9752021
# 22           rdf2vec-cbow-128-autoencoded  Regression    6591527
# 23        rdf2vec-cbow-oa-128-autoencoded  Regression    6589734
# 24             rdf2vec-sg-128-autoencoded  Regression    5572764
# 25          rdf2vec-sg-oa-128-autoencoded  Regression    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  Regression    6622879
# 27   non-rdf2vec-DistMult-128-autoencoded  Regression    6622879
# 28     non-rdf2vec-RESCAL-128-autoencoded  Regression    6622879
# 29     non-rdf2vec-RotatE-128-autoencoded  Regression    6622879
# 30  non-rdf2vec-TransE-L1-128-autoencoded  Regression    6622879
# 31  non-rdf2vec-TransE-L2-128-autoencoded  Regression    6622879
# 32     non-rdf2vec-TransR-128-autoencoded  Regression    6622879
# 33           rdf2vec-cbow-256-autoencoded  Regression   12105767
# 34        rdf2vec-cbow-oa-256-autoencoded  Regression   12102694
# 35             rdf2vec-sg-256-autoencoded  Regression   10228380
# 36          rdf2vec-sg-oa-256-autoencoded  Regression   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  Regression   12163743
# 38   non-rdf2vec-DistMult-256-autoencoded  Regression   12163743
# 39     non-rdf2vec-RESCAL-256-autoencoded  Regression   12163743
# 40     non-rdf2vec-RotatE-256-autoencoded  Regression   12163743
# 41  non-rdf2vec-TransE-L1-256-autoencoded  Regression   12163743
# 42  non-rdf2vec-TransE-L2-256-autoencoded  Regression   12163743
# 43     non-rdf2vec-TransR-256-autoencoded  Regression   12163743
# 44           rdf2vec-cbow-512-autoencoded  Regression   23134247
# 45        rdf2vec-cbow-oa-512-autoencoded  Regression   23128614
# 46             rdf2vec-sg-512-autoencoded  Regression   19539612
# 47          rdf2vec-sg-oa-512-autoencoded  Regression   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  Regression   23245471
# 49   non-rdf2vec-DistMult-512-autoencoded  Regression   23245471
# 50     non-rdf2vec-RESCAL-512-autoencoded  Regression   23245471
# 51     non-rdf2vec-RotatE-512-autoencoded  Regression   23245471
# 52  non-rdf2vec-TransE-L1-512-autoencoded  Regression   23245471
# 53  non-rdf2vec-TransE-L2-512-autoencoded  Regression   23245471
# 54     non-rdf2vec-TransR-512-autoencoded  Regression   23245471
#
#        time_to_run
# 0  00:02:15.617759
# 1  00:02:24.144746
# 2  00:02:09.025446
# 3  00:02:21.740381
# 4  00:02:32.347417
# 5  00:02:34.835933
# 6  00:02:46.442763
# 7  00:02:29.824746
# 8  00:02:23.887291
# 9  00:02:24.781230
# 10 00:02:11.266465
# 11 00:01:09.321254
# 12 00:01:11.812805
# 13 00:01:02.099977
# 14 00:01:08.933952
# 15 00:01:14.209113
# 16 00:01:14.931694
# 17 00:01:12.959434
# 18 00:01:13.701322
# 19 00:01:13.366285
# 20 00:01:10.127743
# 21 00:01:12.738495
# 22 00:00:43.781300
# 23 00:00:43.710402
# 24 00:00:36.915507
# 25 00:00:43.179058
# 26 00:00:44.788126
# 27 00:00:47.420491
# 28 00:00:43.416565
# 29 00:00:45.455934
# 30 00:00:44.952744
# 31 00:00:42.014552
# 32 00:00:44.558098
# 33 00:01:34.950610
# 34 00:01:36.486354
# 35 00:01:19.310520
# 36 00:01:33.173377
# 37 00:01:39.062548
# 38 00:01:39.245227
# 39 00:01:35.741495
# 40 00:01:38.518075
# 41 00:01:39.012763
# 42 00:01:32.052773
# 43 00:01:38.131976
# 44 00:03:45.591735
# 45 00:03:44.935146
# 46 00:03:09.155354
# 47 00:03:35.446543
# 48 00:03:50.375801
# 49 00:03:47.812066
# 50 00:03:31.181700
# 51 00:03:56.811613
# 52 00:03:48.517520
# 53 00:03:38.175392
# 54 00:03:45.196148

# %%
task_name = 'Classification'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
metadata_df.to_csv(f'{task_name}_metadata.csv', index=False)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Classification finished
# 0:15:50
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Classification finished
# 0:15:54
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Classification finished
# 0:13:11
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Classification finished
# 0:15:32
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Classification finished
# 0:16:14
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Classification finished
# 0:16:07
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Classification finished
# 0:15:46
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Classification finished
# 0:16:13
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Classification finished
# 0:15:47
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Classification finished
# 0:14:47
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Classification finished
# 0:15:25
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:01
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Classification finished
# 0:14:59
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Classification finished
# 0:13:09
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:02
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:14
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:21
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Classification finished
# 0:14:54
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:21
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Classification finished
# 0:14:59
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Classification finished
# 0:14:20
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:01
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:42
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:35
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Classification finished
# 0:08:01
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:25
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:44
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:45
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:36
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:48
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:35
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:25
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Classification finished
# 0:09:41
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:10
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:08
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Classification finished
# 0:16:54
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Classification finished
# 0:19:45
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:25
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:32
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Classification finished
# 0:19:48
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:39
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:13
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Classification finished
# 0:18:59
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:15
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:11
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:10
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Classification finished
# 0:36:26
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Classification finished
# 0:43:10
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Classification finished
# 0:45:01
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Classification finished
# 0:45:07
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Classification finished
# 0:43:02
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Classification finished
# 0:45:20
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:28
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Classification finished
# 0:41:22
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:48

# %%
metadata_df
# Out:
#                            embedding_file       task_name  file_size  \
# 0               rdf2vec-cbow-200-original  Classification   88101211
# 1            rdf2vec-cbow-oa-200-original  Classification   89030608
# 2                 rdf2vec-sg-200-original  Classification   74793299
# 3              rdf2vec-sg-oa-200-original  Classification   87883088
# 4        non-rdf2vec-ComplEx-200-original  Classification   88154366
# 5       non-rdf2vec-DistMult-200-original  Classification   88088311
# 6         non-rdf2vec-RESCAL-200-original  Classification   89677247
# 7         non-rdf2vec-RotatE-200-original  Classification   90695298
# 8      non-rdf2vec-TransE-L1-200-original  Classification   91713818
# 9      non-rdf2vec-TransE-L2-200-original  Classification   87218400
# 10        non-rdf2vec-TransR-200-original  Classification   92994398
# 11                rdf2vec-cbow-200-avgbin  Classification    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  Classification    9690774
# 13                  rdf2vec-sg-200-avgbin  Classification    8199564
# 14               rdf2vec-sg-oa-200-avgbin  Classification    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  Classification    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  Classification    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  Classification    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  Classification    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  Classification    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  Classification    9752021
# 21          non-rdf2vec-TransR-200-avgbin  Classification    9752021
# 22           rdf2vec-cbow-128-autoencoded  Classification    6591527
# 23        rdf2vec-cbow-oa-128-autoencoded  Classification    6589734
# 24             rdf2vec-sg-128-autoencoded  Classification    5572764
# 25          rdf2vec-sg-oa-128-autoencoded  Classification    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  Classification    6622879
# 27   non-rdf2vec-DistMult-128-autoencoded  Classification    6622879
# 28     non-rdf2vec-RESCAL-128-autoencoded  Classification    6622879
# 29     non-rdf2vec-RotatE-128-autoencoded  Classification    6622879
# 30  non-rdf2vec-TransE-L1-128-autoencoded  Classification    6622879
# 31  non-rdf2vec-TransE-L2-128-autoencoded  Classification    6622879
# 32     non-rdf2vec-TransR-128-autoencoded  Classification    6622879
# 33           rdf2vec-cbow-256-autoencoded  Classification   12105767
# 34        rdf2vec-cbow-oa-256-autoencoded  Classification   12102694
# 35             rdf2vec-sg-256-autoencoded  Classification   10228380
# 36          rdf2vec-sg-oa-256-autoencoded  Classification   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  Classification   12163743
# 38   non-rdf2vec-DistMult-256-autoencoded  Classification   12163743
# 39     non-rdf2vec-RESCAL-256-autoencoded  Classification   12163743
# 40     non-rdf2vec-RotatE-256-autoencoded  Classification   12163743
# 41  non-rdf2vec-TransE-L1-256-autoencoded  Classification   12163743
# 42  non-rdf2vec-TransE-L2-256-autoencoded  Classification   12163743
# 43     non-rdf2vec-TransR-256-autoencoded  Classification   12163743
# 44           rdf2vec-cbow-512-autoencoded  Classification   23134247
# 45        rdf2vec-cbow-oa-512-autoencoded  Classification   23128614
# 46             rdf2vec-sg-512-autoencoded  Classification   19539612
# 47          rdf2vec-sg-oa-512-autoencoded  Classification   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  Classification   23245471
# 49   non-rdf2vec-DistMult-512-autoencoded  Classification   23245471
# 50     non-rdf2vec-RESCAL-512-autoencoded  Classification   23245471
# 51     non-rdf2vec-RotatE-512-autoencoded  Classification   23245471
# 52  non-rdf2vec-TransE-L1-512-autoencoded  Classification   23245471
# 53  non-rdf2vec-TransE-L2-512-autoencoded  Classification   23245471
# 54     non-rdf2vec-TransR-512-autoencoded  Classification   23245471
#
#        time_to_run
# 0  00:15:51.201508
# 1  00:15:54.788892
# 2  00:13:12.096213
# 3  00:15:32.784851
# 4  00:16:15.257581
# 5  00:16:07.862739
# 6  00:15:47.011247
# 7  00:16:14.271388
# 8  00:15:47.893422
# 9  00:14:48.120111
# 10 00:15:26.109858
# 11 00:15:01.779238
# 12 00:15:00.099408
# 13 00:13:10.147880
# 14 00:15:03.046181
# 15 00:15:15.038759
# 16 00:15:22.719360
# 17 00:14:55.592852
# 18 00:15:22.313608
# 19 00:15:00.298358
# 20 00:14:21.782405
# 21 00:15:02.193199
# 22 00:09:42.870606
# 23 00:09:36.428569
# 24 00:08:01.998683
# 25 00:09:26.290616
# 26 00:09:45.722254
# 27 00:09:46.314058
# 28 00:09:37.596116
# 29 00:09:49.516993
# 30 00:09:36.688874
# 31 00:09:26.448686
# 32 00:09:42.069877
# 33 00:20:11.787323
# 34 00:20:09.033548
# 35 00:16:55.296404
# 36 00:19:46.436375
# 37 00:20:26.729580
# 38 00:20:33.737391
# 39 00:19:49.742698
# 40 00:20:40.407311
# 41 00:20:14.224744
# 42 00:19:00.294077
# 43 00:20:16.650122
# 44 00:44:12.086866
# 45 00:44:11.216021
# 46 00:36:27.239302
# 47 00:43:11.668710
# 48 00:45:02.258376
# 49 00:45:08.348249
# 50 00:43:03.125860
# 51 00:45:21.378294
# 52 00:44:29.458627
# 53 00:41:23.146060
# 54 00:44:49.765738
