# %% [markdown]
# # Run GEval experiments
#
# This notebook consists of running the GEval Evaluation Framework with DBpedia gold standards on a list of previously computed embedding files (obtained with the notebook `get_vectors_pipeline.ipynb`). Results are analyzed in a separate notebook (`analyze_geval.ipynb`).
#
# ### Setup before running this notebook for the first time:
#
# 1. Clone the GEval repo (from Pellegrino et al.) to the folder `geval`.
#
# ```
# git clone https://github.com/mariaangelapellegrino/Evaluation-Framework.git geval
# ```
#
# 2. Move this notebook, the pickle file `geval_entities.pickle`, and the complete `embeddings` folder to `geval`.
#
# The complete execution of all tasks for all 55 variants may take up to 24 hours. Results will be saved in a newly created `comparison.csv` file

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from datetime import datetime 
import time
from os import stat
import pandas as pd
from time import sleep
import pickle


with open('geval_entities.pickle', 'rb') as file:
    geval_entities = pickle.load(file)

# %%
# !mkdir geval_embeddings

# %%
embedding_models = [
    'rdf2vec-cbow',
    'rdf2vec-cbow-oa',
    'rdf2vec-sg',
    'rdf2vec-sg-oa',
    'non-rdf2vec-ComplEx',
    'non-rdf2vec-DistMult',
    'non-rdf2vec-RESCAL',
    'non-rdf2vec-RotatE',
    'non-rdf2vec-TransE-L1',
    'non-rdf2vec-TransE-L2',
    'non-rdf2vec-TransR',
]

model_variants = [
    '-200-original',
    '-200-avgbin',
    '-128-autoencoded',
    '-256-autoencoded',
    '-512-autoencoded',
]

embedding_txt_filenames = [em+mv for mv in model_variants for em in embedding_models]

for embedding_txt_filename in embedding_txt_filenames:
    with open(f"embeddings/{embedding_txt_filename}.txt", "r") as file:
        lines = file.readlines()

    with open(f"geval_embeddings/geval-{embedding_txt_filename}.txt", "w") as file:
        rows_count = 0
        for line in lines:
            if line.split()[0] in geval_entities:
                file.write(line)
                rows_count += 1
    
    print(f"geval_embeddings/geval-{embedding_txt_filename}.txt : {rows_count} entities filtered")
# Out:
# geval_embeddings/geval-rdf2vec-cbow-200-original.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-200-original.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-200-original.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-200-original.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-200-original.txt : 21672 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-200-avgbin.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-200-avgbin.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-200-avgbin.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-200-avgbin.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-200-avgbin.txt : 21672 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-128-autoencoded.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-128-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-128-autoencoded.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-128-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-128-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-256-autoencoded.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-256-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-256-autoencoded.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-256-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-256-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-512-autoencoded.txt : 21568 entities filtered
# geval_embeddings/geval-rdf2vec-cbow-oa-512-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-rdf2vec-sg-512-autoencoded.txt : 18204 entities filtered
# geval_embeddings/geval-rdf2vec-sg-oa-512-autoencoded.txt : 21535 entities filtered
# geval_embeddings/geval-non-rdf2vec-ComplEx-512-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-DistMult-512-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RESCAL-512-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-RotatE-512-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L1-512-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransE-L2-512-autoencoded.txt : 21672 entities filtered
# geval_embeddings/geval-non-rdf2vec-TransR-512-autoencoded.txt : 21672 entities filtered

# %%
from evaluation_framework.manager import FrameworkManager

evaluation_manager = FrameworkManager()
# Out:
# Start evaluation...

# %%
def run_task_for_all_vectors(task_name, embedding_txt_filenames, similarity_metric='manhattan', top_k=10):
    metadata_json = []
    for embedding_txt_filename in embedding_txt_filenames:
        file_size = stat(f"geval_embeddings/geval-{embedding_txt_filename}.txt")
        vector_size = int(embedding_txt_filename.split('-')[-2])
        print(f"Vector file: {embedding_txt_filename}; Dimensions: {vector_size}")

        start_time = datetime.now() 
        evaluation_manager.evaluate(
            f"geval_embeddings/geval-{embedding_txt_filename}.txt",
            vector_size=vector_size,
            debugging_mode=False,
            tasks=[task_name],
            similarity_metric=similarity_metric,
            top_k=top_k,
        )
        end_time = datetime.now()
        metadata_json.append({
            "embedding_file": embedding_txt_filename,
            "task_name": task_name,
            "file_size": file_size.st_size,
            "time_to_run": end_time - start_time,
        })
        sleep(1)
        
    return metadata_json

# %%
task_name = 'DocumentSimilarity'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Document similarity finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Document similarity finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Document similarity finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Document similarity finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Document similarity finished

# %%
metadata_df
# Out:
#                            embedding_file           task_name  file_size  \
# 0               rdf2vec-cbow-200-original  DocumentSimilarity   88101211
# 1            rdf2vec-cbow-oa-200-original  DocumentSimilarity   89030608
# 2                 rdf2vec-sg-200-original  DocumentSimilarity   74793299
# 3              rdf2vec-sg-oa-200-original  DocumentSimilarity   87883088
# 4        non-rdf2vec-ComplEx-200-original  DocumentSimilarity   88154366
# 5       non-rdf2vec-DistMult-200-original  DocumentSimilarity   88088311
# 6         non-rdf2vec-RESCAL-200-original  DocumentSimilarity   89677247
# 7         non-rdf2vec-RotatE-200-original  DocumentSimilarity   90695298
# 8      non-rdf2vec-TransE-L1-200-original  DocumentSimilarity   91713818
# 9      non-rdf2vec-TransE-L2-200-original  DocumentSimilarity   87218400
# 10        non-rdf2vec-TransR-200-original  DocumentSimilarity   92994398
# 11                rdf2vec-cbow-200-avgbin  DocumentSimilarity    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  DocumentSimilarity    9690774
# 13                  rdf2vec-sg-200-avgbin  DocumentSimilarity    8199564
# 14               rdf2vec-sg-oa-200-avgbin  DocumentSimilarity    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  DocumentSimilarity    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  DocumentSimilarity    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  DocumentSimilarity    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  DocumentSimilarity    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  DocumentSimilarity    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  DocumentSimilarity    9752021
# 21          non-rdf2vec-TransR-200-avgbin  DocumentSimilarity    9752021
# 22           rdf2vec-cbow-128-autoencoded  DocumentSimilarity    6599901
# 23        rdf2vec-cbow-oa-128-autoencoded  DocumentSimilarity    6589734
# 24             rdf2vec-sg-128-autoencoded  DocumentSimilarity    5578188
# 25          rdf2vec-sg-oa-128-autoencoded  DocumentSimilarity    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  DocumentSimilarity    6631253
# 27   non-rdf2vec-DistMult-128-autoencoded  DocumentSimilarity    6631253
# 28     non-rdf2vec-RESCAL-128-autoencoded  DocumentSimilarity    6631253
# 29     non-rdf2vec-RotatE-128-autoencoded  DocumentSimilarity    6631253
# 30  non-rdf2vec-TransE-L1-128-autoencoded  DocumentSimilarity    6631253
# 31  non-rdf2vec-TransE-L2-128-autoencoded  DocumentSimilarity    6631253
# 32     non-rdf2vec-TransR-128-autoencoded  DocumentSimilarity    6631253
# 33           rdf2vec-cbow-256-autoencoded  DocumentSimilarity   12121309
# 34        rdf2vec-cbow-oa-256-autoencoded  DocumentSimilarity   12102694
# 35             rdf2vec-sg-256-autoencoded  DocumentSimilarity   10238412
# 36          rdf2vec-sg-oa-256-autoencoded  DocumentSimilarity   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  DocumentSimilarity   12179285
# 38   non-rdf2vec-DistMult-256-autoencoded  DocumentSimilarity   12179285
# 39     non-rdf2vec-RESCAL-256-autoencoded  DocumentSimilarity   12179285
# 40     non-rdf2vec-RotatE-256-autoencoded  DocumentSimilarity   12179285
# 41  non-rdf2vec-TransE-L1-256-autoencoded  DocumentSimilarity   12179285
# 42  non-rdf2vec-TransE-L2-256-autoencoded  DocumentSimilarity   12179285
# 43     non-rdf2vec-TransR-256-autoencoded  DocumentSimilarity   12179285
# 44           rdf2vec-cbow-512-autoencoded  DocumentSimilarity   23164125
# 45        rdf2vec-cbow-oa-512-autoencoded  DocumentSimilarity   23128614
# 46             rdf2vec-sg-512-autoencoded  DocumentSimilarity   19558860
# 47          rdf2vec-sg-oa-512-autoencoded  DocumentSimilarity   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  DocumentSimilarity   23275349
# 49   non-rdf2vec-DistMult-512-autoencoded  DocumentSimilarity   23275349
# 50     non-rdf2vec-RESCAL-512-autoencoded  DocumentSimilarity   23275349
# 51     non-rdf2vec-RotatE-512-autoencoded  DocumentSimilarity   23275349
# 52  non-rdf2vec-TransE-L1-512-autoencoded  DocumentSimilarity   23275349
# 53  non-rdf2vec-TransE-L2-512-autoencoded  DocumentSimilarity   23275349
# 54     non-rdf2vec-TransR-512-autoencoded  DocumentSimilarity   23275349
#
#        time_to_run
# 0  00:00:27.523149
# 1  00:00:12.765897
# 2  00:00:15.068538
# 3  00:00:15.838230
# 4  00:00:15.304203
# 5  00:00:14.346491
# 6  00:00:15.998940
# 7  00:00:16.275585
# 8  00:00:14.589539
# 9  00:00:14.387379
# 10 00:00:15.352921
# 11 00:00:14.505054
# 12 00:00:13.504029
# 13 00:00:14.478701
# 14 00:00:14.849856
# 15 00:00:13.832646
# 16 00:00:13.962649
# 17 00:00:14.010944
# 18 00:00:14.682639
# 19 00:00:13.876673
# 20 00:00:13.894241
# 21 00:00:13.704221
# 22 00:00:10.548046
# 23 00:00:10.986361
# 24 00:00:11.200412
# 25 00:00:10.655459
# 26 00:00:10.594208
# 27 00:00:10.764139
# 28 00:00:12.748860
# 29 00:00:10.800085
# 30 00:00:10.300189
# 31 00:00:10.291848
# 32 00:00:12.370630
# 33 00:00:20.313943
# 34 00:00:16.553385
# 35 00:00:29.797323
# 36 00:00:19.124987
# 37 00:00:20.838330
# 38 00:00:24.744365
# 39 00:00:17.957828
# 40 00:00:16.708436
# 41 00:00:17.026143
# 42 00:00:16.721703
# 43 00:00:15.663955
# 44 00:00:31.997777
# 45 00:00:31.564121
# 46 00:00:32.014249
# 47 00:00:31.571135
# 48 00:00:31.105804
# 49 00:00:32.325357
# 50 00:00:31.214832
# 51 00:00:34.238126
# 52 00:00:31.903818
# 53 00:00:30.750970
# 54 00:00:29.350136

# %%
task_name = 'EntityRelatedness'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames, similarity_metric='cosine')
metadata_df = pd.DataFrame(metadata_json)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Entity Relatedness finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Entity Relatedness finished

# %%
metadata_df
# Out:
#                            embedding_file          task_name  file_size  \
# 0               rdf2vec-cbow-200-original  EntityRelatedness   88101211
# 1            rdf2vec-cbow-oa-200-original  EntityRelatedness   89030608
# 2                 rdf2vec-sg-200-original  EntityRelatedness   74793299
# 3              rdf2vec-sg-oa-200-original  EntityRelatedness   87883088
# 4        non-rdf2vec-ComplEx-200-original  EntityRelatedness   88154366
# 5       non-rdf2vec-DistMult-200-original  EntityRelatedness   88088311
# 6         non-rdf2vec-RESCAL-200-original  EntityRelatedness   89677247
# 7         non-rdf2vec-RotatE-200-original  EntityRelatedness   90695298
# 8      non-rdf2vec-TransE-L1-200-original  EntityRelatedness   91713818
# 9      non-rdf2vec-TransE-L2-200-original  EntityRelatedness   87218400
# 10        non-rdf2vec-TransR-200-original  EntityRelatedness   92994398
# 11                rdf2vec-cbow-200-avgbin  EntityRelatedness    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  EntityRelatedness    9690774
# 13                  rdf2vec-sg-200-avgbin  EntityRelatedness    8199564
# 14               rdf2vec-sg-oa-200-avgbin  EntityRelatedness    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  EntityRelatedness    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  EntityRelatedness    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  EntityRelatedness    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  EntityRelatedness    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  EntityRelatedness    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  EntityRelatedness    9752021
# 21          non-rdf2vec-TransR-200-avgbin  EntityRelatedness    9752021
# 22           rdf2vec-cbow-128-autoencoded  EntityRelatedness    6599901
# 23        rdf2vec-cbow-oa-128-autoencoded  EntityRelatedness    6589734
# 24             rdf2vec-sg-128-autoencoded  EntityRelatedness    5578188
# 25          rdf2vec-sg-oa-128-autoencoded  EntityRelatedness    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  EntityRelatedness    6631253
# 27   non-rdf2vec-DistMult-128-autoencoded  EntityRelatedness    6631253
# 28     non-rdf2vec-RESCAL-128-autoencoded  EntityRelatedness    6631253
# 29     non-rdf2vec-RotatE-128-autoencoded  EntityRelatedness    6631253
# 30  non-rdf2vec-TransE-L1-128-autoencoded  EntityRelatedness    6631253
# 31  non-rdf2vec-TransE-L2-128-autoencoded  EntityRelatedness    6631253
# 32     non-rdf2vec-TransR-128-autoencoded  EntityRelatedness    6631253
# 33           rdf2vec-cbow-256-autoencoded  EntityRelatedness   12121309
# 34        rdf2vec-cbow-oa-256-autoencoded  EntityRelatedness   12102694
# 35             rdf2vec-sg-256-autoencoded  EntityRelatedness   10238412
# 36          rdf2vec-sg-oa-256-autoencoded  EntityRelatedness   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  EntityRelatedness   12179285
# 38   non-rdf2vec-DistMult-256-autoencoded  EntityRelatedness   12179285
# 39     non-rdf2vec-RESCAL-256-autoencoded  EntityRelatedness   12179285
# 40     non-rdf2vec-RotatE-256-autoencoded  EntityRelatedness   12179285
# 41  non-rdf2vec-TransE-L1-256-autoencoded  EntityRelatedness   12179285
# 42  non-rdf2vec-TransE-L2-256-autoencoded  EntityRelatedness   12179285
# 43     non-rdf2vec-TransR-256-autoencoded  EntityRelatedness   12179285
# 44           rdf2vec-cbow-512-autoencoded  EntityRelatedness   23164125
# 45        rdf2vec-cbow-oa-512-autoencoded  EntityRelatedness   23128614
# 46             rdf2vec-sg-512-autoencoded  EntityRelatedness   19558860
# 47          rdf2vec-sg-oa-512-autoencoded  EntityRelatedness   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  EntityRelatedness   23275349
# 49   non-rdf2vec-DistMult-512-autoencoded  EntityRelatedness   23275349
# 50     non-rdf2vec-RESCAL-512-autoencoded  EntityRelatedness   23275349
# 51     non-rdf2vec-RotatE-512-autoencoded  EntityRelatedness   23275349
# 52  non-rdf2vec-TransE-L1-512-autoencoded  EntityRelatedness   23275349
# 53  non-rdf2vec-TransE-L2-512-autoencoded  EntityRelatedness   23275349
# 54     non-rdf2vec-TransR-512-autoencoded  EntityRelatedness   23275349
#
#        time_to_run
# 0  00:00:02.006970
# 1  00:00:01.845845
# 2  00:00:02.054639
# 3  00:00:01.776899
# 4  00:00:01.810365
# 5  00:00:02.325595
# 6  00:00:01.734417
# 7  00:00:01.973014
# 8  00:00:02.011721
# 9  00:00:01.774146
# 10 00:00:02.284376
# 11 00:00:01.130618
# 12 00:00:01.092982
# 13 00:00:00.987496
# 14 00:00:01.082951
# 15 00:00:01.145151
# 16 00:00:01.165757
# 17 00:00:01.093383
# 18 00:00:01.174992
# 19 00:00:01.519156
# 20 00:00:01.093148
# 21 00:00:01.105822
# 22 00:00:00.886797
# 23 00:00:00.915662
# 24 00:00:00.809520
# 25 00:00:00.855102
# 26 00:00:00.857238
# 27 00:00:00.922221
# 28 00:00:00.872297
# 29 00:00:00.880334
# 30 00:00:00.855350
# 31 00:00:01.594165
# 32 00:00:00.909503
# 33 00:00:01.406096
# 34 00:00:01.285088
# 35 00:00:01.150423
# 36 00:00:01.241636
# 37 00:00:01.325192
# 38 00:00:01.371561
# 39 00:00:01.585114
# 40 00:00:01.424472
# 41 00:00:01.326212
# 42 00:00:01.248414
# 43 00:00:01.306403
# 44 00:00:02.467288
# 45 00:00:02.122086
# 46 00:00:01.904874
# 47 00:00:02.145768
# 48 00:00:02.357691
# 49 00:00:02.270778
# 50 00:00:02.265052
# 51 00:00:02.347084
# 52 00:00:02.281298
# 53 00:00:02.998442
# 54 00:00:02.437775

# %%
task_name = 'SemanticAnalogies'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Semantic Analogies finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Semantic Analogies finished

# %%
metadata_df
# Out:
#                            embedding_file          task_name  file_size  \
# 0               rdf2vec-cbow-200-original  SemanticAnalogies   88101211
# 1            rdf2vec-cbow-oa-200-original  SemanticAnalogies   89030608
# 2                 rdf2vec-sg-200-original  SemanticAnalogies   74793299
# 3              rdf2vec-sg-oa-200-original  SemanticAnalogies   87883088
# 4        non-rdf2vec-ComplEx-200-original  SemanticAnalogies   88154366
# 5       non-rdf2vec-DistMult-200-original  SemanticAnalogies   88088311
# 6         non-rdf2vec-RESCAL-200-original  SemanticAnalogies   89677247
# 7         non-rdf2vec-RotatE-200-original  SemanticAnalogies   90695298
# 8      non-rdf2vec-TransE-L1-200-original  SemanticAnalogies   91713818
# 9      non-rdf2vec-TransE-L2-200-original  SemanticAnalogies   87218400
# 10        non-rdf2vec-TransR-200-original  SemanticAnalogies   92994398
# 11                rdf2vec-cbow-200-avgbin  SemanticAnalogies    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  SemanticAnalogies    9690774
# 13                  rdf2vec-sg-200-avgbin  SemanticAnalogies    8199564
# 14               rdf2vec-sg-oa-200-avgbin  SemanticAnalogies    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  SemanticAnalogies    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  SemanticAnalogies    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  SemanticAnalogies    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  SemanticAnalogies    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  SemanticAnalogies    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  SemanticAnalogies    9752021
# 21          non-rdf2vec-TransR-200-avgbin  SemanticAnalogies    9752021
# 22           rdf2vec-cbow-128-autoencoded  SemanticAnalogies    6599901
# 23        rdf2vec-cbow-oa-128-autoencoded  SemanticAnalogies    6589734
# 24             rdf2vec-sg-128-autoencoded  SemanticAnalogies    5578188
# 25          rdf2vec-sg-oa-128-autoencoded  SemanticAnalogies    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  SemanticAnalogies    6631253
# 27   non-rdf2vec-DistMult-128-autoencoded  SemanticAnalogies    6631253
# 28     non-rdf2vec-RESCAL-128-autoencoded  SemanticAnalogies    6631253
# 29     non-rdf2vec-RotatE-128-autoencoded  SemanticAnalogies    6631253
# 30  non-rdf2vec-TransE-L1-128-autoencoded  SemanticAnalogies    6631253
# 31  non-rdf2vec-TransE-L2-128-autoencoded  SemanticAnalogies    6631253
# 32     non-rdf2vec-TransR-128-autoencoded  SemanticAnalogies    6631253
# 33           rdf2vec-cbow-256-autoencoded  SemanticAnalogies   12121309
# 34        rdf2vec-cbow-oa-256-autoencoded  SemanticAnalogies   12102694
# 35             rdf2vec-sg-256-autoencoded  SemanticAnalogies   10238412
# 36          rdf2vec-sg-oa-256-autoencoded  SemanticAnalogies   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  SemanticAnalogies   12179285
# 38   non-rdf2vec-DistMult-256-autoencoded  SemanticAnalogies   12179285
# 39     non-rdf2vec-RESCAL-256-autoencoded  SemanticAnalogies   12179285
# 40     non-rdf2vec-RotatE-256-autoencoded  SemanticAnalogies   12179285
# 41  non-rdf2vec-TransE-L1-256-autoencoded  SemanticAnalogies   12179285
# 42  non-rdf2vec-TransE-L2-256-autoencoded  SemanticAnalogies   12179285
# 43     non-rdf2vec-TransR-256-autoencoded  SemanticAnalogies   12179285
# 44           rdf2vec-cbow-512-autoencoded  SemanticAnalogies   23164125
# 45        rdf2vec-cbow-oa-512-autoencoded  SemanticAnalogies   23128614
# 46             rdf2vec-sg-512-autoencoded  SemanticAnalogies   19558860
# 47          rdf2vec-sg-oa-512-autoencoded  SemanticAnalogies   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  SemanticAnalogies   23275349
# 49   non-rdf2vec-DistMult-512-autoencoded  SemanticAnalogies   23275349
# 50     non-rdf2vec-RESCAL-512-autoencoded  SemanticAnalogies   23275349
# 51     non-rdf2vec-RotatE-512-autoencoded  SemanticAnalogies   23275349
# 52  non-rdf2vec-TransE-L1-512-autoencoded  SemanticAnalogies   23275349
# 53  non-rdf2vec-TransE-L2-512-autoencoded  SemanticAnalogies   23275349
# 54     non-rdf2vec-TransR-512-autoencoded  SemanticAnalogies   23275349
#
#        time_to_run
# 0  00:00:23.638591
# 1  00:00:22.914469
# 2  00:00:01.151807
# 3  00:00:23.890708
# 4  00:00:23.162130
# 5  00:00:24.192060
# 6  00:00:23.089034
# 7  00:00:24.986332
# 8  00:00:24.174404
# 9  00:00:23.232815
# 10 00:00:25.400446
# 11 00:00:22.146111
# 12 00:00:22.191182
# 13 00:00:00.524481
# 14 00:00:22.264552
# 15 00:00:22.854192
# 16 00:00:22.532323
# 17 00:00:22.091398
# 18 00:00:23.714210
# 19 00:00:24.906808
# 20 00:00:22.438216
# 21 00:00:22.848818
# 22 00:00:20.411392
# 23 00:00:19.015374
# 24 00:00:00.927941
# 25 00:00:20.246990
# 26 00:00:20.676803
# 27 00:00:22.198869
# 28 00:00:18.429419
# 29 00:00:18.982683
# 30 00:00:24.422525
# 31 00:00:22.464483
# 32 00:00:19.636319
# 33 00:00:24.969915
# 34 00:00:23.904242
# 35 00:00:00.606847
# 36 00:00:27.641773
# 37 00:00:27.540810
# 38 00:00:27.241129
# 39 00:00:28.418044
# 40 00:00:25.652406
# 41 00:00:25.940038
# 42 00:00:26.447397
# 43 00:00:25.975793
# 44 00:00:43.114079
# 45 00:00:38.248689
# 46 00:00:01.120268
# 47 00:00:39.788209
# 48 00:00:39.488636
# 49 00:00:38.778167
# 50 00:00:41.446328
# 51 00:00:39.977675
# 52 00:00:40.679152
# 53 00:00:42.616625
# 54 00:00:42.303295

# %%
task_name = 'Clustering'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Clustering finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Clustering finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Clustering finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Clustering finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Clustering finished

# %%
metadata_df
# Out:
#                            embedding_file   task_name  file_size  \
# 0               rdf2vec-cbow-200-original  Clustering   88101211
# 1            rdf2vec-cbow-oa-200-original  Clustering   89030608
# 2                 rdf2vec-sg-200-original  Clustering   74793299
# 3              rdf2vec-sg-oa-200-original  Clustering   87883088
# 4        non-rdf2vec-ComplEx-200-original  Clustering   88154366
# 5       non-rdf2vec-DistMult-200-original  Clustering   88088311
# 6         non-rdf2vec-RESCAL-200-original  Clustering   89677247
# 7         non-rdf2vec-RotatE-200-original  Clustering   90695298
# 8      non-rdf2vec-TransE-L1-200-original  Clustering   91713818
# 9      non-rdf2vec-TransE-L2-200-original  Clustering   87218400
# 10        non-rdf2vec-TransR-200-original  Clustering   92994398
# 11                rdf2vec-cbow-200-avgbin  Clustering    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  Clustering    9690774
# 13                  rdf2vec-sg-200-avgbin  Clustering    8199564
# 14               rdf2vec-sg-oa-200-avgbin  Clustering    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  Clustering    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  Clustering    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  Clustering    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  Clustering    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  Clustering    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  Clustering    9752021
# 21          non-rdf2vec-TransR-200-avgbin  Clustering    9752021
# 22           rdf2vec-cbow-128-autoencoded  Clustering    6599901
# 23        rdf2vec-cbow-oa-128-autoencoded  Clustering    6589734
# 24             rdf2vec-sg-128-autoencoded  Clustering    5578188
# 25          rdf2vec-sg-oa-128-autoencoded  Clustering    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  Clustering    6631253
# 27   non-rdf2vec-DistMult-128-autoencoded  Clustering    6631253
# 28     non-rdf2vec-RESCAL-128-autoencoded  Clustering    6631253
# 29     non-rdf2vec-RotatE-128-autoencoded  Clustering    6631253
# 30  non-rdf2vec-TransE-L1-128-autoencoded  Clustering    6631253
# 31  non-rdf2vec-TransE-L2-128-autoencoded  Clustering    6631253
# 32     non-rdf2vec-TransR-128-autoencoded  Clustering    6631253
# 33           rdf2vec-cbow-256-autoencoded  Clustering   12121309
# 34        rdf2vec-cbow-oa-256-autoencoded  Clustering   12102694
# 35             rdf2vec-sg-256-autoencoded  Clustering   10238412
# 36          rdf2vec-sg-oa-256-autoencoded  Clustering   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  Clustering   12179285
# 38   non-rdf2vec-DistMult-256-autoencoded  Clustering   12179285
# 39     non-rdf2vec-RESCAL-256-autoencoded  Clustering   12179285
# 40     non-rdf2vec-RotatE-256-autoencoded  Clustering   12179285
# 41  non-rdf2vec-TransE-L1-256-autoencoded  Clustering   12179285
# 42  non-rdf2vec-TransE-L2-256-autoencoded  Clustering   12179285
# 43     non-rdf2vec-TransR-256-autoencoded  Clustering   12179285
# 44           rdf2vec-cbow-512-autoencoded  Clustering   23164125
# 45        rdf2vec-cbow-oa-512-autoencoded  Clustering   23128614
# 46             rdf2vec-sg-512-autoencoded  Clustering   19558860
# 47          rdf2vec-sg-oa-512-autoencoded  Clustering   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  Clustering   23275349
# 49   non-rdf2vec-DistMult-512-autoencoded  Clustering   23275349
# 50     non-rdf2vec-RESCAL-512-autoencoded  Clustering   23275349
# 51     non-rdf2vec-RotatE-512-autoencoded  Clustering   23275349
# 52  non-rdf2vec-TransE-L1-512-autoencoded  Clustering   23275349
# 53  non-rdf2vec-TransE-L2-512-autoencoded  Clustering   23275349
# 54     non-rdf2vec-TransR-512-autoencoded  Clustering   23275349
#
#        time_to_run
# 0  00:01:18.502461
# 1  00:00:44.059722
# 2  00:00:27.683736
# 3  00:00:39.516318
# 4  00:00:32.459968
# 5  00:00:35.592732
# 6  00:00:33.832913
# 7  00:00:40.219248
# 8  00:00:53.039863
# 9  00:00:40.695957
# 10 00:00:41.122811
# 11 00:01:05.820466
# 12 00:01:21.189990
# 13 00:00:54.420049
# 14 00:01:24.313350
# 15 00:01:23.881437
# 16 00:01:37.835595
# 17 00:01:18.742750
# 18 00:00:52.909968
# 19 00:01:13.222764
# 20 00:01:29.022239
# 21 00:01:07.036109
# 22 00:01:02.321314
# 23 00:00:58.248199
# 24 00:00:38.292215
# 25 00:01:03.023038
# 26 00:01:03.976419
# 27 00:01:05.407407
# 28 00:01:06.179294
# 29 00:00:44.780648
# 30 00:01:06.265573
# 31 00:00:58.432745
# 32 00:00:59.940004
# 33 00:01:25.176715
# 34 00:01:44.249149
# 35 00:01:29.353796
# 36 00:01:50.305262
# 37 00:02:00.156336
# 38 00:02:11.583911
# 39 00:02:18.458984
# 40 00:01:05.650440
# 41 00:01:27.217489
# 42 00:01:36.505168
# 43 00:01:27.499201
# 44 00:03:30.953027
# 45 00:03:24.891612
# 46 00:02:33.272684
# 47 00:03:34.041881
# 48 00:04:05.192682
# 49 00:04:17.906704
# 50 00:03:25.186334
# 51 00:01:57.769901
# 52 00:02:57.274640
# 53 00:03:03.953194
# 54 00:02:35.193630

# %%
task_name = 'Regression'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Regression finished
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Regression finished
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Regression finished
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-TransE-L1-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-TransE-L2-512-autoencoded; Dimensions: 512
# Regression finished
# Vector file: non-rdf2vec-TransR-512-autoencoded; Dimensions: 512
# Regression finished

# %%
metadata_df
# Out:
#                            embedding_file   task_name  file_size  \
# 0               rdf2vec-cbow-200-original  Regression   88101211
# 1            rdf2vec-cbow-oa-200-original  Regression   89030608
# 2                 rdf2vec-sg-200-original  Regression   74793299
# 3              rdf2vec-sg-oa-200-original  Regression   87883088
# 4        non-rdf2vec-ComplEx-200-original  Regression   88154366
# 5       non-rdf2vec-DistMult-200-original  Regression   88088311
# 6         non-rdf2vec-RESCAL-200-original  Regression   89677247
# 7         non-rdf2vec-RotatE-200-original  Regression   90695298
# 8      non-rdf2vec-TransE-L1-200-original  Regression   91713818
# 9      non-rdf2vec-TransE-L2-200-original  Regression   87218400
# 10        non-rdf2vec-TransR-200-original  Regression   92994398
# 11                rdf2vec-cbow-200-avgbin  Regression    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  Regression    9690774
# 13                  rdf2vec-sg-200-avgbin  Regression    8199564
# 14               rdf2vec-sg-oa-200-avgbin  Regression    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  Regression    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  Regression    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  Regression    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  Regression    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  Regression    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  Regression    9752021
# 21          non-rdf2vec-TransR-200-avgbin  Regression    9752021
# 22           rdf2vec-cbow-128-autoencoded  Regression    6599901
# 23        rdf2vec-cbow-oa-128-autoencoded  Regression    6589734
# 24             rdf2vec-sg-128-autoencoded  Regression    5578188
# 25          rdf2vec-sg-oa-128-autoencoded  Regression    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  Regression    6631253
# 27   non-rdf2vec-DistMult-128-autoencoded  Regression    6631253
# 28     non-rdf2vec-RESCAL-128-autoencoded  Regression    6631253
# 29     non-rdf2vec-RotatE-128-autoencoded  Regression    6631253
# 30  non-rdf2vec-TransE-L1-128-autoencoded  Regression    6631253
# 31  non-rdf2vec-TransE-L2-128-autoencoded  Regression    6631253
# 32     non-rdf2vec-TransR-128-autoencoded  Regression    6631253
# 33           rdf2vec-cbow-256-autoencoded  Regression   12121309
# 34        rdf2vec-cbow-oa-256-autoencoded  Regression   12102694
# 35             rdf2vec-sg-256-autoencoded  Regression   10238412
# 36          rdf2vec-sg-oa-256-autoencoded  Regression   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  Regression   12179285
# 38   non-rdf2vec-DistMult-256-autoencoded  Regression   12179285
# 39     non-rdf2vec-RESCAL-256-autoencoded  Regression   12179285
# 40     non-rdf2vec-RotatE-256-autoencoded  Regression   12179285
# 41  non-rdf2vec-TransE-L1-256-autoencoded  Regression   12179285
# 42  non-rdf2vec-TransE-L2-256-autoencoded  Regression   12179285
# 43     non-rdf2vec-TransR-256-autoencoded  Regression   12179285
# 44           rdf2vec-cbow-512-autoencoded  Regression   23164125
# 45        rdf2vec-cbow-oa-512-autoencoded  Regression   23128614
# 46             rdf2vec-sg-512-autoencoded  Regression   19558860
# 47          rdf2vec-sg-oa-512-autoencoded  Regression   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  Regression   23275349
# 49   non-rdf2vec-DistMult-512-autoencoded  Regression   23275349
# 50     non-rdf2vec-RESCAL-512-autoencoded  Regression   23275349
# 51     non-rdf2vec-RotatE-512-autoencoded  Regression   23275349
# 52  non-rdf2vec-TransE-L1-512-autoencoded  Regression   23275349
# 53  non-rdf2vec-TransE-L2-512-autoencoded  Regression   23275349
# 54     non-rdf2vec-TransR-512-autoencoded  Regression   23275349
#
#        time_to_run
# 0  00:02:21.194312
# 1  00:02:31.134330
# 2  00:02:25.145999
# 3  00:02:39.107541
# 4  00:02:48.427155
# 5  00:02:41.679470
# 6  00:02:57.722374
# 7  00:02:45.466372
# 8  00:04:10.687646
# 9  00:02:36.573481
# 10 00:02:33.058926
# 11 00:01:24.170026
# 12 00:01:31.026525
# 13 00:01:09.209175
# 14 00:01:19.488047
# 15 00:01:23.803369
# 16 00:01:21.820144
# 17 00:01:18.414971
# 18 00:01:21.386796
# 19 00:01:19.437041
# 20 00:01:17.108958
# 21 00:01:20.046193
# 22 00:00:47.480735
# 23 00:00:48.258529
# 24 00:00:41.028572
# 25 00:00:47.142610
# 26 00:00:49.128199
# 27 00:00:49.037005
# 28 00:00:46.953980
# 29 00:00:48.816397
# 30 00:00:49.515079
# 31 00:00:46.651141
# 32 00:00:49.235315
# 33 00:01:50.981291
# 34 00:01:41.370550
# 35 00:01:27.004714
# 36 00:01:34.340995
# 37 00:01:43.490939
# 38 00:01:47.598110
# 39 00:01:43.622448
# 40 00:01:48.385266
# 41 00:01:45.320083
# 42 00:01:39.415978
# 43 00:01:46.697662
# 44 00:04:07.954805
# 45 00:03:54.488001
# 46 00:03:19.471116
# 47 00:03:55.963041
# 48 00:04:03.218174
# 49 00:04:18.606198
# 50 00:04:09.900952
# 51 00:04:05.467330
# 52 00:04:02.601408
# 53 00:03:59.357615
# 54 00:04:19.531907

# %%
task_name = 'Classification'
metadata_json = run_task_for_all_vectors(task_name, embedding_txt_filenames)
metadata_df = pd.DataFrame(metadata_json)
# Out:
# Vector file: rdf2vec-cbow-200-original; Dimensions: 200
# Classification finished
# 0:16:21
# Vector file: rdf2vec-cbow-oa-200-original; Dimensions: 200
# Classification finished
# 0:16:35
# Vector file: rdf2vec-sg-200-original; Dimensions: 200
# Classification finished
# 0:14:00
# Vector file: rdf2vec-sg-oa-200-original; Dimensions: 200
# Classification finished
# 0:16:08
# Vector file: non-rdf2vec-ComplEx-200-original; Dimensions: 200
# Classification finished
# 0:17:21
# Vector file: non-rdf2vec-DistMult-200-original; Dimensions: 200
# Classification finished
# 0:17:18
# Vector file: non-rdf2vec-RESCAL-200-original; Dimensions: 200
# Classification finished
# 0:16:43
# Vector file: non-rdf2vec-RotatE-200-original; Dimensions: 200
# Classification finished
# 0:17:14
# Vector file: non-rdf2vec-TransE-L1-200-original; Dimensions: 200
# Classification finished
# 0:16:56
# Vector file: non-rdf2vec-TransE-L2-200-original; Dimensions: 200
# Classification finished
# 0:15:51
# Vector file: non-rdf2vec-TransR-200-original; Dimensions: 200
# Classification finished
# 0:16:25
# Vector file: rdf2vec-cbow-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:01
# Vector file: rdf2vec-cbow-oa-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:00
# Vector file: rdf2vec-sg-200-avgbin; Dimensions: 200
# Classification finished
# 0:13:59
# Vector file: rdf2vec-sg-oa-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:57
# Vector file: non-rdf2vec-ComplEx-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:15
# Vector file: non-rdf2vec-DistMult-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:24
# Vector file: non-rdf2vec-RESCAL-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:00
# Vector file: non-rdf2vec-RotatE-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:25
# Vector file: non-rdf2vec-TransE-L1-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:03
# Vector file: non-rdf2vec-TransE-L2-200-avgbin; Dimensions: 200
# Classification finished
# 0:15:20
# Vector file: non-rdf2vec-TransR-200-avgbin; Dimensions: 200
# Classification finished
# 0:16:09
# Vector file: rdf2vec-cbow-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:35
# Vector file: rdf2vec-cbow-oa-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:12
# Vector file: rdf2vec-sg-128-autoencoded; Dimensions: 128
# Classification finished
# 0:08:38
# Vector file: rdf2vec-sg-oa-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:10
# Vector file: non-rdf2vec-ComplEx-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:16
# Vector file: non-rdf2vec-DistMult-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:40
# Vector file: non-rdf2vec-RESCAL-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:28
# Vector file: non-rdf2vec-RotatE-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:26
# Vector file: non-rdf2vec-TransE-L1-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:27
# Vector file: non-rdf2vec-TransE-L2-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:16
# Vector file: non-rdf2vec-TransR-128-autoencoded; Dimensions: 128
# Classification finished
# 0:10:12
# Vector file: rdf2vec-cbow-256-autoencoded; Dimensions: 256
# Classification finished
# 0:22:01
# Vector file: rdf2vec-cbow-oa-256-autoencoded; Dimensions: 256
# Classification finished
# 0:21:32
# Vector file: rdf2vec-sg-256-autoencoded; Dimensions: 256
# Classification finished
# 0:18:08
# Vector file: rdf2vec-sg-oa-256-autoencoded; Dimensions: 256
# Classification finished
# 0:21:36
# Vector file: non-rdf2vec-ComplEx-256-autoencoded; Dimensions: 256
# Classification finished
# 0:22:24
# Vector file: non-rdf2vec-DistMult-256-autoencoded; Dimensions: 256
# Classification finished
# 0:22:00
# Vector file: non-rdf2vec-RESCAL-256-autoencoded; Dimensions: 256
# Classification finished
# 0:21:40
# Vector file: non-rdf2vec-RotatE-256-autoencoded; Dimensions: 256
# Classification finished
# 0:22:14
# Vector file: non-rdf2vec-TransE-L1-256-autoencoded; Dimensions: 256
# Classification finished
# 0:21:40
# Vector file: non-rdf2vec-TransE-L2-256-autoencoded; Dimensions: 256
# Classification finished
# 0:20:34
# Vector file: non-rdf2vec-TransR-256-autoencoded; Dimensions: 256
# Classification finished
# 0:21:54
# Vector file: rdf2vec-cbow-512-autoencoded; Dimensions: 512
# Classification finished
# 0:47:36
# Vector file: rdf2vec-cbow-oa-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:30
# Vector file: rdf2vec-sg-512-autoencoded; Dimensions: 512
# Classification finished
# 0:36:52
# Vector file: rdf2vec-sg-oa-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:48
# Vector file: non-rdf2vec-ComplEx-512-autoencoded; Dimensions: 512
# Classification finished
# 0:47:38
# Vector file: non-rdf2vec-DistMult-512-autoencoded; Dimensions: 512
# Classification finished
# 0:46:48
# Vector file: non-rdf2vec-RESCAL-512-autoencoded; Dimensions: 512
# Classification finished
# 0:44:18
# Vector file: non-rdf2vec-RotatE-512-autoencoded; Dimensions: 512

# %%
metadata_df
# Out:
#                            embedding_file       task_name  file_size  \
# 0               rdf2vec-cbow-200-original  Classification   88101211
# 1            rdf2vec-cbow-oa-200-original  Classification   89030608
# 2                 rdf2vec-sg-200-original  Classification   74793299
# 3              rdf2vec-sg-oa-200-original  Classification   87883088
# 4        non-rdf2vec-ComplEx-200-original  Classification   88154366
# 5       non-rdf2vec-DistMult-200-original  Classification   88088311
# 6         non-rdf2vec-RESCAL-200-original  Classification   89677247
# 7         non-rdf2vec-RotatE-200-original  Classification   90695298
# 8      non-rdf2vec-TransE-L1-200-original  Classification   91713818
# 9      non-rdf2vec-TransE-L2-200-original  Classification   87218400
# 10        non-rdf2vec-TransR-200-original  Classification   92994398
# 11                rdf2vec-cbow-200-avgbin  Classification    9705693
# 12             rdf2vec-cbow-oa-200-avgbin  Classification    9690774
# 13                  rdf2vec-sg-200-avgbin  Classification    8199564
# 14               rdf2vec-sg-oa-200-avgbin  Classification    9690774
# 15         non-rdf2vec-ComplEx-200-avgbin  Classification    9752021
# 16        non-rdf2vec-DistMult-200-avgbin  Classification    9752021
# 17          non-rdf2vec-RESCAL-200-avgbin  Classification    9752021
# 18          non-rdf2vec-RotatE-200-avgbin  Classification    9752021
# 19       non-rdf2vec-TransE-L1-200-avgbin  Classification    9752021
# 20       non-rdf2vec-TransE-L2-200-avgbin  Classification    9752021
# 21          non-rdf2vec-TransR-200-avgbin  Classification    9752021
# 22           rdf2vec-cbow-128-autoencoded  Classification    6599901
# 23        rdf2vec-cbow-oa-128-autoencoded  Classification    6589734
# 24             rdf2vec-sg-128-autoencoded  Classification    5578188
# 25          rdf2vec-sg-oa-128-autoencoded  Classification    6589734
# 26    non-rdf2vec-ComplEx-128-autoencoded  Classification    6631253
# 27   non-rdf2vec-DistMult-128-autoencoded  Classification    6631253
# 28     non-rdf2vec-RESCAL-128-autoencoded  Classification    6631253
# 29     non-rdf2vec-RotatE-128-autoencoded  Classification    6631253
# 30  non-rdf2vec-TransE-L1-128-autoencoded  Classification    6631253
# 31  non-rdf2vec-TransE-L2-128-autoencoded  Classification    6631253
# 32     non-rdf2vec-TransR-128-autoencoded  Classification    6631253
# 33           rdf2vec-cbow-256-autoencoded  Classification   12121309
# 34        rdf2vec-cbow-oa-256-autoencoded  Classification   12102694
# 35             rdf2vec-sg-256-autoencoded  Classification   10238412
# 36          rdf2vec-sg-oa-256-autoencoded  Classification   12102694
# 37    non-rdf2vec-ComplEx-256-autoencoded  Classification   12179285
# 38   non-rdf2vec-DistMult-256-autoencoded  Classification   12179285
# 39     non-rdf2vec-RESCAL-256-autoencoded  Classification   12179285
# 40     non-rdf2vec-RotatE-256-autoencoded  Classification   12179285
# 41  non-rdf2vec-TransE-L1-256-autoencoded  Classification   12179285
# 42  non-rdf2vec-TransE-L2-256-autoencoded  Classification   12179285
# 43     non-rdf2vec-TransR-256-autoencoded  Classification   12179285
# 44           rdf2vec-cbow-512-autoencoded  Classification   23164125
# 45        rdf2vec-cbow-oa-512-autoencoded  Classification   23128614
# 46             rdf2vec-sg-512-autoencoded  Classification   19558860
# 47          rdf2vec-sg-oa-512-autoencoded  Classification   23128614
# 48    non-rdf2vec-ComplEx-512-autoencoded  Classification   23275349
# 49   non-rdf2vec-DistMult-512-autoencoded  Classification   23275349
# 50     non-rdf2vec-RESCAL-512-autoencoded  Classification   23275349
# 51     non-rdf2vec-RotatE-512-autoencoded  Classification   23275349
# 52  non-rdf2vec-TransE-L1-512-autoencoded  Classification   23275349
# 53  non-rdf2vec-TransE-L2-512-autoencoded  Classification   23275349
# 54     non-rdf2vec-TransR-512-autoencoded  Classification   23275349
#
#        time_to_run
# 0  00:16:22.440418
# 1  00:16:36.508233
# 2  00:14:01.079060
# 3  00:16:09.781790
# 4  00:17:22.456304
# 5  00:17:18.902092
# 6  00:16:44.570921
# 7  00:17:15.122072
# 8  00:16:56.870397
# 9  00:15:52.286560
# 10 00:16:26.388142
# 11 00:16:02.107865
# 12 00:16:01.465301
# 13 00:13:59.998663
# 14 00:15:58.453404
# 15 00:16:16.428868
# 16 00:16:24.981372
# 17 00:16:01.625728
# 18 00:16:26.558039
# 19 00:16:04.703338
# 20 00:15:21.803997
# 21 00:16:10.893608
# 22 00:10:36.388443
# 23 00:10:13.496598
# 24 00:08:39.150524
# 25 00:10:10.877633
# 26 00:10:17.688185
# 27 00:10:41.085052
# 28 00:10:29.677797
# 29 00:10:27.664045
# 30 00:10:28.824037
# 31 00:10:17.640211
# 32 00:10:13.909922
# 33 00:22:02.360781
# 34 00:21:33.658121
# 35 00:18:09.567612
# 36 00:21:37.076923
# 37 00:22:25.082597
# 38 00:22:01.532118
# 39 00:21:41.384838
# 40 00:22:15.990974
# 41 00:21:41.503037
# 42 00:20:35.573374
# 43 00:21:55.919995
# 44 00:47:37.856294
# 45 00:44:31.716086
# 46 00:36:53.547211
# 47 00:44:49.488052
# 48 00:47:39.898752
# 49 00:46:54.245011
# 50 00:44:19.685754
# 51 00:49:39.183832
# 52 00:45:10.924095
# 53 00:41:53.546930
# 54 00:44:44.855660
